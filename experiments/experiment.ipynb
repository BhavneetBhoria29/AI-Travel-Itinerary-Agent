# %% [markdown]
# SETUP OR FETCH OUR ENV VARIABLES

# %%
from dotenv import load_dotenv
import os

load_dotenv()

print("keys set!")
# Out:
# keys set!

# %%
from langchain_anthropic import ChatAnthropic

model = ChatAnthropic(
    model="claude-sonnet-4-6",
    temperature=0.2,
    max_tokens=1024
)

response = model.invoke("Hello, Claude!")
print(response)
# Out:
# content='Hello! How are you doing today? Is there something I can help you with, or did you just want to say hi? 😊' additional_kwargs={} response_metadata={'id': 'msg_01RGEXMxV6LyXfWQJGNHcgzX', 'container': None, 'model': 'claude-sonnet-4-6', 'stop_details': None, 'stop_reason': 'end_turn', 'stop_sequence': None, 'usage': {'cache_creation': {'ephemeral_1h_input_tokens': 0, 'ephemeral_5m_input_tokens': 0}, 'cache_creation_input_tokens': 0, 'cache_read_input_tokens': 0, 'inference_geo': 'global', 'input_tokens': 11, 'output_tokens': 32, 'server_tool_use': None, 'service_tier': 'standard'}, 'model_name': 'claude-sonnet-4-6', 'model_provider': 'anthropic'} id='lc_run--019e02fa-e3af-7221-941c-c12abda81cea-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 11, 'output_tokens': 32, 'total_tokens': 43, 'input_token_details': {'cache_read': 0, 'cache_creation': 0, 'ephemeral_5m_input_tokens': 0, 'ephemeral_1h_input_tokens': 0}}

# %%
from langchain_tavily import TavilySearch

tavily_search= TavilySearch(

    max_results=5,
    topic= "general"
)
print("Tavily search tool ready")
# Out:
# Tavily search tool ready

# %%
from langchain_community.utilities import GoogleSerperAPIWrapper


google_search= GoogleSerperAPIWrapper()

print("Google serper wrapper ready")
# Out:
# Google serper wrapper ready

# %%
result=google_search.run("best places to visit in Bali travel guide")
print(result)
# Out:
# The Best Places to Visit in Bali · Canggu · Uluwatu · Sanur · Nusa Lembongan & Nusa Ceningan · Nusa Penida · Ubud · Bonus: Gili Trawangan · That's my guide to the best ... The best places to stay in Bali for first-timers are Seminyak, Ubud, and Canggu. However, depending on your requirements, you might want to ... From the picturesque waterfalls around Ubud and ancient temples like Gunung Kawi, to Instagrammable cafés and black sand beaches. Canggu: Chill Surf Town and Digital Nomad Hub · Ubud: Culture, Nature, and Wellness · Uluwatu: Beaches, Cliffs, and Sunset Views · Seminyak: ... A comprehensive travel guide and a collection of tips for visiting Bali, Indonesia from the experts at Condé Nast Traveler. Even if you don't surf just make sure you visit Uluwatu. It's remote, relaxed and has some of the best beaches you'll see. We booked in to padang padang surf ... From what we have read, areas like Seminyak and Canggu are great for partying, but Ubud offers an incredible cultural experience. Most people choose Canggu or Seminyak on the southwest coast of Bali. Seminyak is an upmarket coastal town with high-end resorts, restaurants and boutiques. Nusa Penida and Gili Islands. For those interested in coastal scenery and island vibes, a segment of the trip could include Nusa Penida and the Gili Islands. A complete Bali travel guide covering Ubud, Sacred Monkey Forest, Tirta Empul, Ulun Danu Beratan, Jatiluwih Rice Terraces, Tanah Lot, ...
